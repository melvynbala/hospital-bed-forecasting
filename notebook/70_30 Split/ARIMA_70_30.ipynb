# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#for plots inside the notebook
# %matplotlib inline

# %%
file_path = "../healthcare_dataset.csv"

df=pd.read_csv(file_path)

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0    18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1    33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2    27955.096079          205      Emergency     2022-10-07      Aspirin
# 3    37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4    14238.317814          458         Urgent     2022-10-09   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %%
df.shape
# Out:
# (55500, 15)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df['Date of Admission']=pd.to_datetime(df['Date of Admission'])
df['Discharge Date']= pd.to_datetime(df['Discharge Date'])

# %%
daily_admissions = df.groupby('Date of Admission').size()

daily_admissions = daily_admissions.rename('admissions')

daily_admissions = daily_admissions.sort_index()

print(daily_admissions.head())
print(daily_admissions.tail())
# Out:
# Date of Admission
# 2019-05-08    27
# 2019-05-09    38
# 2019-05-10    17
# 2019-05-11    25
# 2019-05-12    36
# Name: admissions, dtype: int64
# Date of Admission
# 2024-05-03    31
# 2024-05-04    24
# 2024-05-05    26
# 2024-05-06    33
# 2024-05-07    33
# Name: admissions, dtype: int64

# %%
daily_admissions = daily_admissions.asfreq("D", fill_value=0)

# %%
plt.figure(figsize=(12, 4))
plt.plot(daily_admissions.index, daily_admissions.values)
plt.title("Daily Hospital Admissions")
plt.xlabel("Date")
plt.ylabel("Number of Admissions")
plt.show()

# %%
rolling_mean = daily_admissions.rolling(window=30).mean()
rolling_std = daily_admissions.rolling(window=30).std()

plt.figure(figsize=(12,5))
plt.plot(daily_admissions, label='Original')
plt.plot(rolling_mean, label='30-day Rolling Mean')
plt.plot(rolling_std, label='30-day Rolling Std')
plt.title("Rolling Mean & Standard Deviation")
plt.legend()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(daily_admissions)

print("ADF Statistic:", result[0])
print("p-value:", result[1])
# Out:
# ADF Statistic: -43.8477001478261
# p-value: 0.0

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.figure(figsize=(12,5))
plot_acf(daily_admissions, ax=plt.gca(), lags=40)
plt.title("ACF Plot")
plt.show()

plt.figure(figsize=(12,5))
plot_pacf(daily_admissions, ax=plt.gca(), lags=40, method='ywm')
plt.title("PACF Plot")
plt.show()

# %%
#Training_Data

daily_admissions = daily_admissions.sort_index()

train_size = int(len(daily_admissions) * 0.7)

train = daily_admissions.iloc[:train_size]
test  = daily_admissions.iloc[train_size:]

print("Total length:", len(daily_admissions))
print("Train length:", len(train))
print("Test length:", len(test))
# Out:
# Total length: 1827
# Train length: 1278
# Test length: 549

# %%
print("\nTrain last dates:")
print(train.tail())

print("\nTest first dates:")
print(test.head())
# Out:
# Train last dates:
# Date of Admission
# 2022-11-01    23
# 2022-11-02    34
# 2022-11-03    35
# 2022-11-04    26
# 2022-11-05    34
# Freq: D, Name: admissions, dtype: int64
#
# Test first dates:
# Date of Admission
# 2022-11-06    28
# 2022-11-07    28
# 2022-11-08    33
# 2022-11-09    25
# 2022-11-10    22
# Freq: D, Name: admissions, dtype: int64

# %%
#ARIMA
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(train, order=(1, 0, 1))
model_fit = model.fit()

print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             admissions   No. Observations:                 1278
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -4119.175
# Date:                Tue, 06 Jan 2026   AIC                           8248.349
# Time:                        14:07:47   BIC                           8274.111
# Sample:                    05-08-2019   HQIC                          8258.024
#                          - 11-05-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4961      0.316     -1.570      0.116      -1.115       0.123
# ar.L2         -0.0655      0.029     -2.292      0.022      -0.122      -0.009
# ma.L1         -0.5158      0.319     -1.618      0.106      -1.141       0.109
# ma.L2         -0.4736      0.317     -1.496      0.135      -1.094       0.147
# sigma2        36.9672      1.486     24.880      0.000      34.055      39.879
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 4.44
# Prob(Q):                              0.98   Prob(JB):                         0.11
# Heteroskedasticity (H):               1.04   Skew:                             0.14
# Prob(H) (two-sided):                  0.68   Kurtosis:                         2.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast for full test period
forecast = model_fit.get_forecast(steps=len(test))
y_pred = forecast.predicted_mean

# Plot
plt.figure(figsize=(12,5))
plt.plot(test.index, test, label="Actual", color="black")
plt.plot(y_pred.index, y_pred, label="Prediction", color="orange")
plt.title("ARIMA: Actual vs Prediction (70/30 split)")
plt.xlabel("Date")
plt.ylabel("Admissions")
plt.legend()
plt.show()

# %%
#70/30 splits

from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.statespace.sarimax import SARIMAX

series = daily_admissions.sort_index()

train_size = int(len(series) * 0.7)
train = series.iloc[:train_size]
test  = series.iloc[train_size:]

print("Train period:", train.index.min(), "to", train.index.max(), "len:", len(train))
print("Test period :", test.index.min(),  "to", test.index.max(),  "len:", len(test))
# Out:
# Train period: 2019-05-08 00:00:00 to 2022-11-05 00:00:00 len: 1278
# Test period : 2022-11-06 00:00:00 to 2024-05-07 00:00:00 len: 549

# %%
arima_model = SARIMAX(
    train,
    order=(1, 0, 1),
    enforce_stationarity=False,
    enforce_invertibility=False
)
arima_result = arima_model.fit(disp=False)

print(arima_result.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             admissions   No. Observations:                 1278
# Model:               SARIMAX(1, 0, 1)   Log Likelihood               -4139.216
# Date:                Tue, 06 Jan 2026   AIC                           8284.431
# Time:                        14:07:28   BIC                           8299.886
# Sample:                    05-08-2019   HQIC                          8290.235
#                          - 11-05-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0000   3.79e-05   2.64e+04      0.000       1.000       1.000
# ma.L1         -0.9960      0.005   -187.637      0.000      -1.006      -0.986
# sigma2        48.3579      2.482     19.482      0.000      43.493      53.223
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.35   Jarque-Bera (JB):                 4.48
# Prob(Q):                              0.55   Prob(JB):                         0.11
# Heteroskedasticity (H):               1.03   Skew:                             0.14
# Prob(H) (two-sided):                  0.75   Kurtosis:                         2.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
forecast = arima_result.get_forecast(steps=len(test))
y_pred = forecast.predicted_mean
y_pred.index = test.index 

y_true = test

rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mae  = mean_absolute_error(y_true, y_pred)
eps = 1e-10
mape = np.mean(np.abs((y_true - y_pred) / (y_true + eps))) * 100
accuracy = 100 - mape 

print("\nARIMA(1,0,1) performance on TEST set (70/30):")
print("RMSE:", rmse)
print("MAE :", mae)
print("MAPE:", mape, "%")
print("Accuracy",accuracy,"%")
# Out:
# ARIMA(1,0,1) performance on TEST set (70/30):
# RMSE: 5.980500956015705
# MAE : 4.815758250147488
# MAPE: 16.755804490030123 %
# Accuracy 83.24419550996987 %

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.plot(y_true.index, y_true, label="Actual (Test)", color="black", linewidth=2)
plt.plot(y_pred.index, y_pred, label="ARIMA Prediction", color="orange", linewidth=2)

plt.title("ARIMA: Actual vs Prediction (70/30 split)")
plt.xlabel("Date")
plt.ylabel("Admissions")
plt.legend()
plt.grid(True)
plt.tight_layout()

# Save the figure as PNG
plt.savefig("arima_actual_vs_prediction_70_30.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
y_test = test

arima_df = pd.DataFrame({
    "date": y_test.index,
    "actual": y_test.values,
    "arima_pred": y_pred.values
})

arima_df.to_csv("../70_30 split/predictions/arima_predictions.csv", index=False)

# %%
print(y_pred_arima[:10])
print(y_pred_arima[-10:])
print("Unique predictions:", len(set(np.round(y_pred_arima, 6))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 print(y_pred_arima[:10])
#       2 print(y_pred_arima[-10:])
#       3 print("Unique predictions:", len(set(np.round(y_pred_arima, 6))))
#
# NameError: name 'y_pred_arima' is not defined

# %%
print(y_pred.describe())
print("Std of forecast:", y_pred.std())
print("Unique values (rounded):", y_pred.round(3).nunique())
# Out:
# count    549.000000
# mean      30.184282
# std        0.018755
# min       29.834177
# 25%       30.184338
# 50%       30.184338
# 75%       30.184338
# max       30.386441
# Name: predicted_mean, dtype: float64
# Std of forecast: 0.0187548792385337
# Unique values (rounded): 8

# %%
test = test.sort_index()
y_pred = y_pred.reindex(test.index)

test_w = test.resample("W").mean()
pred_w = y_pred.resample("W").mean()

plt.figure(figsize=(12,5))
plt.plot(test_w.index, test_w.values, label="Actual (Weekly Mean)", color="black", linewidth=2)
plt.plot(pred_w.index, pred_w.values, label="ARIMA Forecast (Weekly Mean)", color="orange", linewidth=2)
plt.title("ARIMA: Actual vs Forecast (Weekly Mean, 70/30 Test Window)")
plt.xlabel("Date"); plt.ylabel("Admissions")
plt.legend(); plt.grid(True)
plt.show()
